# %%
from sudokupy.python_code.sudokupy_gen import sudokupy_gen

# Generate 10 Sudoku puzzles and their solutions
puzzles_and_solutions = sudokupy_gen(10)

# Print each puzzle and its solution
for idx, (puzzle, solution) in enumerate(puzzles_and_solutions, 1):
    print(f"Puzzle {idx}:\n{puzzle}\n")
    print(f"Solution {idx}:\n{solution}\n")
